# %%
import requests
from bs4 import BeautifulSoup
import time
import random
import pandas as pd

# %%
head ={'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
       'accept-encoding': 'gzip, deflate, br',
       'accept-language': 'fr-FR,fr;q=0.9,es-ES;q=0.8,es;q=0.7,en-US;q=0.6,en;q=0.5,la;q=0.4',
       'Cookie': "CTK=1ec2qan6pq2ma800; _ga=GA1.2.1480736921.1593527593; _gcl_au=1.1.866743975.1593527613; JCLK=1; RF=\"TFTzyBUJoNr6YttPP3kyivpZ6-9J49o-Uk3iY6QNQqKE2fh7FyVgtWFBsuN5UtuLz_MWBBiO8Xw=\"; g_state={\"i_l\":0}; optimizelyEndUserId=oeu1594026206066r0.5768540165703828; OptanonAlertBoxClosed=2020-08-03T08:31:59.644Z; _gid=GA1.2.863213106.1599396400; OptanonConsent=isIABGlobal=false&datestamp=Mon+Sep+07+2020+12%3A19%3A25+GMT%2B0200+(Central+European+Summer+Time)&version=6.3.0&consentId=4b932611-d37e-4b98-9ee6-5ffcb5a758aa&interactionCount=2&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A1%2CC0003%3A1%2CC0004%3A1&hosts=&AwaitingReconsent=false&geolocation=%3B",
       'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.149 Safari/537.36'}

# %%
url='https://www.indeed.fr/jobs?q=Alternance+Data&l=Paris+%2875%29&fromage=3'
r=requests.get(url,headers=head)
print(url)
print(r.status_code)
soup = BeautifulSoup(r.content,"html")
time.sleep(random.randrange(0,2))
for elem in soup.findAll('a',{'data-tn-element':'jobTitle'}):
        print('#################################')
        print(elem.text.strip())
# Out:
# https://www.indeed.fr/jobs?q=Alternance+Data&l=Paris+%2875%29&fromage=3
# 200
# #################################
# Assistant de direction H/F - Alternance/Apprentissage/Profes...
# #################################
# Développeur.se Web – Stage/Alternance (F/H)
# #################################
# CHARGEE DE PROJETS RH F/H
# #################################
# Chargé de projet digital Marketing Epargne
# #################################
# DATA ANALYST (M/F/D) - ALTERNANCE
# #################################
# Assistant de direction H/F - Alternance/Apprentissage/Profes...
# #################################
# Chargé de recrutement - Professionnalisation/Apprentissage/A...
# #################################
# Data Scientist
# #################################
# Développeur Python / Sneakers Bot - Alternance
# #################################
# Alternance - Chargé(e) de développement RH
# #################################
# ASSISTANT MARKETING DIGITAL EN ALTERNANCE
# #################################
# Alternance - Data manager
# #################################
# ALTERNANCE - Analyste développeur SQL/VBA H/F
# #################################
# Alternance - Assistant du Manager
# #################################
# Assistant de gestion en alternance H/F
# #################################
# Assistant administratif et commercial H/F - Alternance - Cha...

# %%
# CHOIX DES VARIABLES DE L'URL:
    # FROMAGE : date de publication 3 = 3 derniers jours : choix entre 3,7,14


# CREATION DE NOS DICTIONNAIRES DE DONNEES FUTURES
title = []
company = []
location = []

# NOMBRE DE PAGE DE 0 à 200 avec un PAS de 10 (fonctionne comme cela dans l'url)
for j in range(0,500,10):
    # HEAD pris dans le navigateur
    head = {'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
       'accept-encoding': 'gzip, deflate, br',
       'accept-language': 'fr-FR,fr;q=0.9,es-ES;q=0.8,es;q=0.7,en-US;q=0.6,en;q=0.5,la;q=0.4',
       'Cookie': "CTK=1ec2qan6pq2ma800; _ga=GA1.2.1480736921.1593527593; _gcl_au=1.1.866743975.1593527613; JCLK=1; RF=\"TFTzyBUJoNr6YttPP3kyivpZ6-9J49o-Uk3iY6QNQqKE2fh7FyVgtWFBsuN5UtuLz_MWBBiO8Xw=\"; g_state={\"i_l\":0}; optimizelyEndUserId=oeu1594026206066r0.5768540165703828; OptanonAlertBoxClosed=2020-08-03T08:31:59.644Z; _gid=GA1.2.863213106.1599396400; OptanonConsent=isIABGlobal=false&datestamp=Mon+Sep+07+2020+12%3A19%3A25+GMT%2B0200+(Central+European+Summer+Time)&version=6.3.0&consentId=4b932611-d37e-4b98-9ee6-5ffcb5a758aa&interactionCount=2&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A1%2CC0003%3A1%2CC0004%3A1&hosts=&AwaitingReconsent=false&geolocation=%3B",
       'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.149 Safari/537.36'}

    # Si nb de page = 0 url simple (finalement inutile, url par défaut)
    #if j == 0:
    #    url ='https://www.indeed.fr/jobs?q=Alternance+Data&l=Paris+%2875%29&fromage=14'
    #else:
    url ='https://www.indeed.fr/jobs?q=Alternance+Data&l=Paris+%2875%29&fromage=3&start='+str(j)

    # Request BS
    r = requests.get(url,headers=head)
    # print(url)
    # print(r.status_code)
    soup = BeautifulSoup(r.content,'html')
#####!!!!!!#######
    
    # Time sleep pour être caché
    time.sleep(random.randrange(0,2))
    
    # Récupérer les éléments TITLE (titre de chaque annonce)
    for elem in soup.findAll('a',{'data-tn-element':'jobTitle'}):
        if elem == None:
            title.append("N/A")
        else:
        #print("c'est la page: "+ str(j))
        #print(elem.text.strip())
            title.append(elem.text.strip())
        
    # Récupérer les éléments COMPANY (entreprise de chaque annonce)
    for elem in soup.findAll('span',{'class':'company'}):
        if elem == None:
            company.append("N/A")
        else:
            company.append(elem.text.strip())  
            

#####!!!!!!######           
#     for elem in soup.findAll('span',{'class':'location accessible-contrast-color-location'}):
#         if elem == None:
#             location.append("N/A")
#         else:
#         #print("c'est la page: "+ str(j))
#         #print(elem.text.strip())
#             location.append(elem.text.strip())
#####!!!!!!######

# %%
## print(offre)
print(len(title))
print(len(company))
print(len(location))
# Out:
# 769
# 769
# 0

# %%
list(zip(title,company))
# Out:
# [('Développeur.se Web – Stage/Alternance (F/H)', 'Novencia'),
#  ('Chargé(e) de communication et marketing digital - Alternance...', 'ISCOD'),
#  ('Chargé de projet digital Marketing Epargne', 'ALLINSOURCING'),
#  ('DATA ANALYST (M/F/D) - ALTERNANCE', 'Chance'),
#  ('Chargé de Dévt Transactions et Location (H/F) en apprentissa...',
#   'LAFORÊT IMMOBILIER'),
#  ('Data Scientist', 'MGEN'),
#  ('Assistant de direction H/F - Alternance/Apprentissage/Profes...',
#   'Formawave'),
#  ('Développeur Python / Sneakers Bot - Alternance', 'Sold Out'),
#  ('Alternance - Chargé(e) de développement RH', 'ESTIAM'),
#  ('ALTERNANCE - Analyste développeur SQL/VBA H/F', 'Crédit Agricole'),
#  ('Alternance - Assistant du Manager', 'SCOR'),
#  ('Chargé de recrutement - Professionnalisation/Apprentissage/A...',
#   'Formawave'),
#  ('ASSISTANT MARKETING DIGITAL EN ALTERNANCE', 'Total'),
#  ('Chargé(e) de communication et marketing digital - Alternance...', 'ISCOD'),
#  ('Alternance - Chargé de projet Process Backoffice H/F', 'Malakoff Humanis'),
#  ('Alternance - Assistant(e) comptable trésorerie (H/F)', 'Devoteam'),
#  ('Apprenti(e) Assistant(e) RH - ALTERNANCE', 'Nexity Property Management'),
#  ('Alternance - Chargé(e) de Communication / Marque Employeur -...', 'Extia'),
#  ('ALTERNANCE- Assistant(e) Administration du Personnel / Paie',
#   'Altares-D&B'),
#  ('Alternance Développeur Full Stack JS 2020', 'Day One'),
#  ('Chargé de vente en alternance', 'Food Love'),
#  ('Chargé de communication junior en alternance', 'Food Love'),
#  ('Alternance - Assistant(E) Achats Et Production PAP Femme (F/...',
#   'Louis Vuitton'),
#  ('Alternance - Data manager', 'Intersport'),
#  ('Assistant(e) de Direction en alternance', 'IDECSI'),
#  ('Chargé de projet digital Marketing Epargne', 'ALLINSOURCING'),
#  ('Assistant administratif et commercial H/F - Alternance - Cha...', 'ISCOD'),
#  ('Développeur.se Web – Stage/Alternance (F/H)', 'Novencia'),
#  ('Chargé(e) de Projets Marketing et Communication Digitale',
#   'PROGRESS SANTE'),
#  ('Assistant administratif et commercial H/F - Alternance - Cha...', 'ISCOD'),
#  ('Alternance développeur fullstack', 'Clubeling'),
#  ('Assistant dentaire en alternance H/F - DENTEGO Voltaire', 'Dentego'),
#  ('Développeur.se Web – Stage/Alternance (F/H)', 'Novencia'),
#  ('Alternance - Assistant(e) formation H/F', 'SMAC'),
#  ('Chargé de Développement Foncier H/F - Alternance', 'SEQENS'),
#  ('Data Scientist', 'Lydia App'),
#  ('Data Scientist F/H', 'Cadreo'),
#  ('DATA ANALYST – CDI (H/F)', 'IRI'),
#  ('"Assistant(e) Sales & Marketing | Alternance | H/F"', 'PwC'),
#  ('Contrat Alternance - Chargé de Communication', 'Klugg'),
#  ('Alternance - Chargé de projet Process Backoffice H/F', 'Malakoff Humanis'),
#  ('Chargé(e) de communication et marketing digital - Alternance...', 'ISCOD'),
#  ('Développeur.se Web – Stage/Alternance (F/H)', 'Novencia'),
#  ('Assistant administratif et commercial H/F - Alternance - Cha...', 'ISCOD'),
#  ('CHARGEE DE PROJETS RH F/H', 'ALIXIO MOBILITÉ'),
#  ('Alternance - Développeur Laravel/VueJS (ou React)', 'WeBoost'),
#  ('Data Engineer', 'Excelya'),
#  ('Chargé(e) de Recrutement en alternance H/F', 'Dentego'),
#  ('Assistant(e) Exploitation en alternance H/F', 'COLAS'),
#  ('Alternance - Developpeur Web H/F', 'Paris Attitude'),
#  ('Assistant(e) de Manager – BTS SAM en alternance - Rentrée Oc...', 'ESAGE'),
#  ('Alternance - Assistant(e) Technique (H/F)', 'ATIXIS'),
#  ('Alternance - AXA Banque - Chargé(e) de projet Multicanal H/F',
#   'Junior Talent'),
#  ('Stage - 6 mois - Data Scientist (H/F) - Paris 13ème', 'NATIXIS'),
#  ('Assistant de gestion en alternance H/F', 'LABORATOIRE CHATEAU ROUGE'),
#  ('Développeur.se Web – Stage/Alternance (F/H)', 'Novencia'),
#  ('Chargé(e) de communication et marketing digital - Alternance...', 'ISCOD'),
#  ('Chargé(e) de Projets Marketing et Communication Digitale',
#   'PROGRESS SANTE'),
#  ('Alternance - Chargé de projet Process Backoffice H/F', 'Malakoff Humanis'),
#  ('CHARGE(E) DE RECRUTEMENT IT Alternance F/H', 'Teolia'),
#  ('Alternance - Chargé de recrutement (H/F)', 'ACTIVUS Group'),
#  ('Assistant(e) Exploitation en alternance H/F',
#   'Colas Ile-de-France Normandie'),
#  ('Alternance - Assistant administratif et financier', 'Linkednutri'),
#  ('Chargée de recrutement (alternance) H/F', 'Aperlead'),
#  ('Data Engineer AWS', 'Getpro'),
#  ('Alternance - Chargé de projet Process Backoffice H/F', 'Malakoff Humanis'),
#  ('Data Engineer', 'Shippeo'),
#  ('Data Analyst F/H', 'Cadreo'),
#  ('Assistant dentaire en alternance H/F - DENTEGO Marx Dormoy', 'Dentego'),
#  ('Assistant administratif et commercial H/F - Alternance - Cha...', 'ISCOD'),
#  ('Développeur.se Web – Stage/Alternance (F/H)', 'Novencia'),
#  ('Chargé(e) de communication et marketing digital - Alternance...', 'ISCOD'),
#  ('Chargé(e) de Projets Marketing et Communication Digitale',
#   'PROGRESS SANTE'),
#  ('Alternance - Chargé de projet Process Backoffice H/F', 'Malakoff Humanis'),
#  ('Alternance - Assistant(e) Qualité Relation Client', 'Audika'),
#  ('Data Analyst - Data Steward F/H', 'Cadreo'),
#  ('Développeur web / mobile Ionic Angular, H/F, 12 mois en alte...',
#   'KOZI TECHNOLOGY'),
#  ("Assistant dentaire en alternance H/F - DENTEGO Porte d'Orlea...",
#   'Dentego'),
#  ('Alternance - Assistant Product Owner', 'La Relève'),
#  ('Alternance/Stage Janvier 2021 - EMEA Employee Experience Ass...',
#   'Ubisoft'),
#  ('ALTERNANCE Assistant(e) Commercial(e)', 'Discovery'),
#  ('Analyste de données F/H', 'Agence nationale des Jeux'),
#  ('DATA SCIENTIST - F/H', 'Ingeniance'),
#  ('ALTERNANCE Assistant(e) développement RH', 'Discovery'),
#  ('Assistant administratif et commercial H/F - Alternance - Cha...', 'ISCOD'),
#  ('Développeur.se Web – Stage/Alternance (F/H)', 'Novencia'),
#  ('Chargé(e) de communication et marketing digital - Alternance...', 'ISCOD'),
#  ('Chargé(e) de Projets Marketing et Communication Digitale',
#   'PROGRESS SANTE'),
#  ('Alternance - Chargé de projet Process Backoffice H/F', 'Malakoff Humanis'),
#  ('Chargé de projet culture, art et territoire - Contrat du 16...',
#   'Seine-Saint-Denis'),
#  ('Chargé(e) de Développement Social, Urbain et Incivilités - E...',
#   'Groupe Poste Habitat - TOIT ET JOIE'),
#  ('DEVELOPPEUR MULTIMEDIA (H/F) EN ALTERNANCE', 'TALENTIS HORIZON'),
#  ('ALTERNANCE Junior Revenue Analyst', 'Discovery'),
#  ('Data Engineer F/H', 'Bluescale'),
#  ('Chargé de projet digital Marketing Epargne', 'ALLINSOURCING'),
#  ('Consultant Data Scientist (H/F)', 'INVENTIV IT'),
#  ('Assistant marketing/commercial en alternance (H/F)', 'TALENTIS HORIZON'),
#  ('Technical Leader Data Engineer F/H', 'Cadreo'),
#  ('Chargé(e) de Projets Marketing et Communication Digitale',
#   'PROGRESS SANTE'),
#  ('Assistant administratif et commercial H/F - Alternance - Cha...', 'ISCOD'),
#  ('Alternance - Chargé de projet Process Backoffice H/F', 'Malakoff Humanis'),
#  ('Développeur.se Web – Stage/Alternance (F/H)', 'Novencia'),
#  ('Chargé(e) de communication et marketing digital - Alternance...', 'ISCOD'),
#  ('Chargé(e) de Projets Marketing et Communication Digitale',
#   'PROGRESS SANTE'),
#  ('EXPERT EN ANALYSES DE DONNEES / DATA SCIENTIST',
#   'CPAM DE LA SEINE-SAINT-DENIS'),
#  ('Assistant Marketing & Social - CONTRAT PRO / ALTERNANCE / ST...', "I'm Ok"),
#  ('Data Manager et Analyste Processus Gestion S&OP et GPEC F/H', 'Cadreo'),
#  ('Junior Data Software Engineer - Warehouse', 'BlaBlaCar'),
#  ('CDI - BIG DATA ENGINEER- F/H', 'Ingeniance'),
#  ('Chargé de Recrutement et Formation (H/F) – Stage ou Alternan...', 'Haier'),
#  ('Senior Data Scientist - Quantitative HFT', 'S.R Investment Partners'),
#  ('CHARGEE DE PROJETS RH F/H', 'ALIXIO MOBILITÉ'),
#  ('DATA SCIENTIST CONFIRME- F/H', 'Ingeniance'),
#  ('Chargé relation client - Energie (F-H) – Paris – Alternance',
#   'Generationnel'),
#  ('Alternance - Chargé de projet Process Backoffice H/F', 'Malakoff Humanis'),
#  ('Assistant administratif et commercial H/F - Alternance - Cha...', 'ISCOD'),
#  ('Développeur.se Web – Stage/Alternance (F/H)', 'Novencia'),
#  ('Chargé(e) de communication et marketing digital - Alternance...', 'ISCOD'),
#  ('Chargé(e) de Projets Marketing et Communication Digitale',
#   'PROGRESS SANTE'),
#  ('Développeur.se Web – Stage/Alternance (F/H)', 'Novencia'),
#  ('Chargé(e) de communication et marketing digital - Alternance...', 'ISCOD'),
#  ('Consultant--Data Analyste', 'Alan Allman Associates'),
#  ('Chargé(e) de Communication Digitale en Alternance H/F', 'DEKRA'),
#  ('Responsable Data Analyst F/H', 'Cadreo'),
#  ('Chargé(e) de projet – Commissariat à l’aménagement, au dével...',
#   'ANCT / AGENCE NATIONALE DE LA COHESION DES TERRITO'),
#  ('Chargé(e) de webmarketing (growth hacking) et communication...',
#   'Tigersun media group'),
#  ('Stagiaire chargé de projets collaboratifs européens', 'Navya'),
#  ('Data Analyste Confirmé (H/F)', 'Monster'),
#  ('Stage Janvier 2021 - EMEA Brand Content Analyst Assistant (H...',
#   'Ubisoft'),
#  ('Chargé de projet Marketing Digital (H/F)', 'Monster'),
#  ('Apprenti(e) HR Data analyst/Chargé de rémunération et contrô...', 'Safran'),
#  ('Chargé(e) de Projets Marketing et Communication Digitale',
#   'PROGRESS SANTE'),
#  ('Alternance - Chargé de projet Process Backoffice H/F', 'Malakoff Humanis'),
#  ('Assistant administratif et commercial H/F - Alternance - Cha...', 'ISCOD'),
#  ('Développeur.se Web – Stage/Alternance (F/H)', 'Novencia'),
#  ('Chargé(e) de communication et marketing digital - Alternance...', 'ISCOD'),
#  ('Lead Data Scientist F/H', 'LittleBigCode'),
#  ('Architecte chargé de projet pour un ensemble tertiaire', 'Highline Paris'),
#  ('Chargé d’affaires / Chef de projet F/H', 'ACH'),
#  ('Chargé(e) de projet pédagogique HSE (F/H)', 'Watura'),
#  ('Chargé de projets packaging (H/F)', 'Lynx RH'),
#  ('Lead Data Engineer F/H', 'LittleBigCode'),
#  ('Data Analyste Confirmé F/H', 'Cadreo'),
#  ('Chargé de projet Alumni (H/F)', 'Efrei'),
#  ('Chargé de support et projets SAP BFC - H/F', 'LEON Recrutement'),
#  ('EXPERT EN ANALYSES DE DONNEES / DATA SCIENTIST',
#   'Union Nationale des Caisses de Sécurité Sociale'),
#  ('Chargé(e) de Projets Marketing et Communication Digitale',
#   'PROGRESS SANTE'),
#  ('Alternance - Chargé de projet Process Backoffice H/F', 'Malakoff Humanis'),
#  ('Assistant administratif et commercial H/F - Alternance - Cha...', 'ISCOD'),
#  ('Alternance - Chargé de projet Process Backoffice H/F', 'Malakoff Humanis'),
#  ('Assistant administratif et commercial H/F - Alternance - Cha...', 'ISCOD'),
#  ('Chef de projet/Chargé.e de mission - Certification - VAE - H...', 'AFPA'),
#  ('Chargé de projet H/F', 'Adéquat'),
#  ('Architecte chargé de projet pour un grand ensemble de logeme...',
#   'Highline Paris'),
#  ('Alternance - Assistant Marketing (H/F)', 'COLLEGE DE PARIS'),
#  ('Manager Reporting Bi - Business Analyst F/H', 'Cadreo'),
#  ('Assistant(e) controleur de gestion en alternance (H/F)',
#   'COLLEGE DE PARIS'),
#  ('Consultant technique Big Data / Data Engineer Confirmé / Sen...',
#   'INVENTIV IT'),
#  ('Développeur.se Web – Stage/Alternance (F/H)', 'Novencia'),
#  ('Chargé(e) de communication et marketing digital - Alternance...', 'ISCOD'),
#  ('Chargé(e) de Projets Marketing et Communication Digitale',
#   'PROGRESS SANTE'),
#  ('Assistant comptable en alternance H/F', 'Akor Alternance'),
#  ('CHARGEE DE PROJETS RH F/H', 'ALIXIO MOBILITÉ'),
#  ('Chargé(e) de webmarketing et communication digitale en Alter...', 'ISCOD'),
#  ('Développeur.se Web – Stage/Alternance (F/H)', 'Novencia'),
#  ('Chargé(e) de communication et marketing digital - Alternance...', 'ISCOD'),
#  ('Chargé de projet Alumni (H/F)', 'Efrei'),
#  ('Chargé de support et projets SAP BFC - H/F', 'LEON Recrutement'),
#  ('EXPERT EN ANALYSES DE DONNEES / DATA SCIENTIST',
#   'Union Nationale des Caisses de Sécurité Sociale'),
#  ('Chef de projet/Chargé.e de mission - Certification - VAE - H...', 'AFPA'),
#  ('Chargé de projet H/F', 'Adéquat'),
#  ('Architecte chargé de projet pour un grand ensemble de logeme...',
#   'Highline Paris'),
#  ('Alternance - Assistant Marketing (H/F)', 'COLLEGE DE PARIS'),
#  ('Manager Reporting Bi - Business Analyst F/H', 'Cadreo'),
#  ('Assistant(e) controleur de gestion en alternance (H/F)',
#   'COLLEGE DE PARIS'),
#  ('Consultant technique Big Data / Data Engineer Confirmé / Sen...',
#   'INVENTIV IT'),
#  ('Assistant administratif et commercial H/F - Alternance - Cha...', 'ISCOD'),
#  ('Chargé(e) de Projets Marketing et Communication Digitale',
#   'PROGRESS SANTE'),
#  ('Alternance - Chargé de projet Process Backoffice H/F', 'Malakoff Humanis'),
#  ('Chargé de projet Alumni (H/F)', 'Efrei'),
#  ('Chargé de support et projets SAP BFC - H/F', 'LEON Recrutement'),
#  ('EXPERT EN ANALYSES DE DONNEES / DATA SCIENTIST',
#   'Union Nationale des Caisses de Sécurité Sociale'),
#  ('Chef de projet/Chargé.e de mission - Certification - VAE - H...', 'AFPA'),
#  ('Chargé de projet H/F', 'Adéquat'),
#  ('Architecte chargé de projet pour un grand ensemble de logeme...',
#   'Highline Paris'),
#  ('Alternance - Assistant Marketing (H/F)', 'COLLEGE DE PARIS'),
#  ('Manager Reporting Bi - Business Analyst F/H', 'Cadreo'),
#  ('Assistant(e) controleur de gestion en alternance (H/F)',
#   'COLLEGE DE PARIS'),
#  ('Consultant technique Big Data / Data Engineer Confirmé / Sen...',
#   'INVENTIV IT'),
#  ('Alternance - Chargé de projet Process Backoffice H/F', 'Malakoff Humanis'),
#  ('Assistant administratif et commercial H/F - Alternance - Cha...', 'ISCOD'),
#  ('Développeur.se Web – Stage/Alternance (F/H)', 'Novencia'),
#  ('Chargé(e) de communication et marketing digital - Alternance...', 'ISCOD'),
#  ('Chargé(e) de Projets Marketing et Communication Digitale',
#   'PROGRESS SANTE'),
#  ('Chargé de projet Alumni (H/F)', 'Efrei'),
#  ('Chargé de support et projets SAP BFC - H/F', 'LEON Recrutement'),
#  ('EXPERT EN ANALYSES DE DONNEES / DATA SCIENTIST',
#   'Union Nationale des Caisses de Sécurité Sociale'),
#  ('Chef de projet/Chargé.e de mission - Certification - VAE - H...', 'AFPA'),
#  ('Chargé de projet H/F', 'Adéquat'),
#  ('Architecte chargé de projet pour un grand ensemble de logeme...',
#   'Highline Paris'),
#  ('Alternance - Assistant Marketing (H/F)', 'COLLEGE DE PARIS'),
#  ('Manager Reporting Bi - Business Analyst F/H', 'Cadreo'),
#  ('Assistant(e) controleur de gestion en alternance (H/F)',
#   'COLLEGE DE PARIS'),
#  ('Consultant technique Big Data / Data Engineer Confirmé / Sen...',
#   'INVENTIV IT'),
#  ('Alternance - Chargé de projet Process Backoffice H/F', 'Malakoff Humanis'),
#  ('Assistant administratif et commercial H/F - Alternance - Cha...', 'ISCOD'),
#  ('Développeur.se Web – Stage/Alternance (F/H)', 'Novencia'),
#  ('Chargé(e) de communication et marketing digital - Alternance...', 'ISCOD'),
#  ('Chargé(e) de Projets Marketing et Communication Digitale',
#   'PROGRESS SANTE'),
#  ('Chargé de projet Alumni (H/F)', 'Efrei'),
#  ('Chargé de support et projets SAP BFC - H/F', 'LEON Recrutement'),
#  ('EXPERT EN ANALYSES DE DONNEES / DATA SCIENTIST',
#   'Union Nationale des Caisses de Sécurité Sociale'),
#  ('Chef de projet/Chargé.e de mission - Certification - VAE - H...', 'AFPA'),
#  ('Chargé de projet H/F', 'Adéquat'),
#  ('Architecte chargé de projet pour un grand ensemble de logeme...',
#   'Highline Paris'),
#  ('Alternance - Assistant Marketing (H/F)', 'COLLEGE DE PARIS'),
#  ('Manager Reporting Bi - Business Analyst F/H', 'Cadreo'),
#  ('Assistant(e) controleur de gestion en alternance (H/F)',
#   'COLLEGE DE PARIS'),
#  ('Consultant technique Big Data / Data Engineer Confirmé / Sen...',
#   'INVENTIV IT'),
#  ('Alternance - Chargé de projet Process Backoffice H/F', 'Malakoff Humanis'),
#  ('Assistant administratif et commercial H/F - Alternance - Cha...', 'ISCOD'),
#  ('Développeur.se Web – Stage/Alternance (F/H)', 'Novencia'),
#  ('Chargé(e) de communication et marketing digital - Alternance...', 'ISCOD'),
#  ('Chargé(e) de Projets Marketing et Communication Digitale',
#   'PROGRESS SANTE'),
#  ('Chargé(e) de Projets Marketing et Communication Digitale',
#   'PROGRESS SANTE'),
#  ('Assistant administratif et commercial H/F - Alternance - Cha...', 'ISCOD'),
#  ('Alternance - Chargé de projet Process Backoffice H/F', 'Malakoff Humanis'),
#  ('Chargé de projet Alumni (H/F)', 'Efrei'),
#  ('Chargé de support et projets SAP BFC - H/F', 'LEON Recrutement'),
#  ('EXPERT EN ANALYSES DE DONNEES / DATA SCIENTIST',
#   'Union Nationale des Caisses de Sécurité Sociale'),
#  ('Chef de projet/Chargé.e de mission - Certification - VAE - H...', 'AFPA'),
#  ('Chargé de projet H/F', 'Adéquat'),
#  ('Architecte chargé de projet pour un grand ensemble de logeme...',
#   'Highline Paris'),
#  ('Alternance - Assistant Marketing (H/F)', 'COLLEGE DE PARIS'),
#  ('Manager Reporting Bi - Business Analyst F/H', 'Cadreo'),
#  ('Assistant(e) controleur de gestion en alternance (H/F)',
#   'COLLEGE DE PARIS'),
#  ('Consultant technique Big Data / Data Engineer Confirmé / Sen...',
#   'INVENTIV IT'),
#  ('Développeur.se Web – Stage/Alternance (F/H)', 'Novencia'),
#  ('Chargé(e) de communication et marketing digital - Alternance...', 'ISCOD'),
#  ('Assistant comptable en alternance H/F', 'Akor Alternance'),
#  ('Assistant administratif et commercial H/F - Alternance - Cha...', 'ISCOD'),
#  ('Alternance - Chargé de projet Process Backoffice H/F', 'Malakoff Humanis'),
#  ('Développeur.se Web – Stage/Alternance (F/H)', 'Novencia'),
#  ('Chargé(e) de communication et marketing digital - Alternance...', 'ISCOD'),
#  ('Chargé(e) de Projets Marketing et Communication Digitale',
#   'PROGRESS SANTE'),
#  ('Chargé de projet Alumni (H/F)', 'Efrei'),
#  ('Chargé de support et projets SAP BFC - H/F', 'LEON Recrutement'),
#  ('EXPERT EN ANALYSES DE DONNEES / DATA SCIENTIST',
#   'Union Nationale des Caisses de Sécurité Sociale'),
#  ('Chef de projet/Chargé.e de mission - Certification - VAE - H...', 'AFPA'),
#  ('Chargé de projet H/F', 'Adéquat'),
#  ('Architecte chargé de projet pour un grand ensemble de logeme...',
#   'Highline Paris'),
#  ('Alternance - Assistant Marketing (H/F)', 'COLLEGE DE PARIS'),
#  ('Manager Reporting Bi - Business Analyst F/H', 'Cadreo'),
#  ('Assistant(e) controleur de gestion en alternance (H/F)',
#   'COLLEGE DE PARIS'),
#  ('Consultant technique Big Data / Data Engineer Confirmé / Sen...',
#   'INVENTIV IT'),
#  ('Assistant administratif et commercial H/F - Alternance - Cha...', 'ISCOD'),
#  ('Assistant comptable en alternance H/F', 'Akor Alternance'),
#  ('Alternance - Chargé de projet Process Backoffice H/F', 'Malakoff Humanis'),
#  ('Développeur.se Web – Stage/Alternance (F/H)', 'Novencia'),
#  ('Chargé(e) de communication et marketing digital - Alternance...', 'ISCOD'),
#  ('Chargé(e) de Projets Marketing et Communication Digitale',
#   'PROGRESS SANTE'),
#  ('Chargé de projet Alumni (H/F)', 'Efrei'),
#  ('Chargé de support et projets SAP BFC - H/F', 'LEON Recrutement'),
#  ('EXPERT EN ANALYSES DE DONNEES / DATA SCIENTIST',
#   'Union Nationale des Caisses de Sécurité Sociale'),
#  ('Chef de projet/Chargé.e de mission - Certification - VAE - H...', 'AFPA'),
#  ('Chargé de projet H/F', 'Adéquat'),
#  ('Architecte chargé de projet pour un grand ensemble de logeme...',
#   'Highline Paris'),
#  ('Alternance - Assistant Marketing (H/F)', 'COLLEGE DE PARIS'),
#  ('Manager Reporting Bi - Business Analyst F/H', 'Cadreo'),
#  ('Assistant(e) controleur de gestion en alternance (H/F)',
#   'COLLEGE DE PARIS'),
#  ('Consultant technique Big Data / Data Engineer Confirmé / Sen...',
#   'INVENTIV IT'),
#  ('Assistant administratif et commercial H/F - Alternance - Cha...', 'ISCOD'),
#  ('Assistant comptable en alternance H/F', 'Akor Alternance'),
#  ('Alternance - Chargé de projet Process Backoffice H/F', 'Malakoff Humanis'),
#  ('Développeur.se Web – Stage/Alternance (F/H)', 'Novencia'),
#  ('Chargé(e) de communication et marketing digital - Alternance...', 'ISCOD'),
#  ('Chargé(e) de Projets Marketing et Communication Digitale',
#   'PROGRESS SANTE'),
#  ('Chargé de projet Alumni (H/F)', 'Efrei'),
#  ('Chargé de support et projets SAP BFC - H/F', 'LEON Recrutement'),
#  ('EXPERT EN ANALYSES DE DONNEES / DATA SCIENTIST',
#   'Union Nationale des Caisses de Sécurité Sociale'),
#  ('Chef de projet/Chargé.e de mission - Certification - VAE - H...', 'AFPA'),
#  ('Chargé de projet H/F', 'Adéquat'),
#  ('Architecte chargé de projet pour un grand ensemble de logeme...',
#   'Highline Paris'),
#  ('Alternance - Assistant Marketing (H/F)', 'COLLEGE DE PARIS'),
#  ('Manager Reporting Bi - Business Analyst F/H', 'Cadreo'),
#  ('Assistant(e) controleur de gestion en alternance (H/F)',
#   'COLLEGE DE PARIS'),
#  ('Consultant technique Big Data / Data Engineer Confirmé / Sen...',
#   'INVENTIV IT'),
#  ('Assistant administratif et commercial H/F - Alternance - Cha...', 'ISCOD'),
#  ('Assistant comptable en alternance H/F', 'Akor Alternance'),
#  ('Alternance - Chargé de projet Process Backoffice H/F', 'Malakoff Humanis'),
#  ('Développeur.se Web – Stage/Alternance (F/H)', 'Novencia'),
#  ('Chargé(e) de communication et marketing digital - Alternance...', 'ISCOD'),
#  ('Chargé(e) de Projets Marketing et Communication Digitale',
#   'PROGRESS SANTE'),
#  ('Chargé de projet Alumni (H/F)', 'Efrei'),
#  ('Chargé de support et projets SAP BFC - H/F', 'LEON Recrutement'),
#  ('EXPERT EN ANALYSES DE DONNEES / DATA SCIENTIST',
#   'Union Nationale des Caisses de Sécurité Sociale'),
#  ('Chef de projet/Chargé.e de mission - Certification - VAE - H...', 'AFPA'),
#  ('Chargé de projet H/F', 'Adéquat'),
#  ('Architecte chargé de projet pour un grand ensemble de logeme...',
#   'Highline Paris'),
#  ('Alternance - Assistant Marketing (H/F)', 'COLLEGE DE PARIS'),
#  ('Manager Reporting Bi - Business Analyst F/H', 'Cadreo'),
#  ('Assistant(e) controleur de gestion en alternance (H/F)',
#   'COLLEGE DE PARIS'),
#  ('Consultant technique Big Data / Data Engineer Confirmé / Sen...',
#   'INVENTIV IT')]

# %%
d = {'Entreprise':company, 'Offre': title,}
df = pd.DataFrame(data=d)
df.to_csv('scrap_indeed.csv',index=False)

# %%
pd.read_csv('scrap_indeed.csv')
# Out:
#                   Entreprise  \
# 0                   Novencia
# 1                      ISCOD
# 2    S.R Investment Partners
# 3                     Chance
# 4         LAFORÊT IMMOBILIER
# ..                       ...
# 764                    ISCOD
# 765                    ISCOD
# 766                 Novencia
# 767         Malakoff Humanis
# 768          Akor Alternance
#
#                                                  Offre
# 0          Développeur.se Web – Stage/Alternance (F/H)
# 1    Chargé(e) de webmarketing et communication dig...
# 2             Senior Data Scientist - Quantitative HFT
# 3                    DATA ANALYST (M/F/D) - ALTERNANCE
# 4    Chargé de Dévt Transactions et Location (H/F) ...
# ..                                                 ...
# 764  Chargé(e) de communication et marketing digita...
# 765  Assistant administratif et commercial H/F - Al...
# 766        Développeur.se Web – Stage/Alternance (F/H)
# 767  Alternance - Chargé de projet Process Backoffi...
# 768              Assistant comptable en alternance H/F
#
# [769 rows x 2 columns]
